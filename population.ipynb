# %% [markdown]
# <a href="https://colab.research.google.com/github/Aminsfwt/Clean-Education-Indicators-using-pandas/blob/main/population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tableau project on education story in this century using data from world bank**
#
# first download Education indecators from world bank in this link:
# https://data.worldbank.org/indicator

# %% [markdown]
# #Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #First load first dataset population

# %%
#load data
df = pd.read_csv("population.csv")

print(df.head())
# Out:
#   Country Name                                     Indicator Name  \
# 0  Afghanistan                                  Population, total
# 1  Afghanistan           Urban population (% of total population)
# 2  Afghanistan  Unemployment, total (% of total labor force) (...
# 3  Afghanistan                       GDP per capita (current US$)
# 4      Albania                                  Population, total
#
#           2000         2001         2002         2003         2004  \
# 0     20130327     20284307     21378117     22733049     23560654
# 1       22.078       22.169       22.261       22.353         22.5
# 2        7.935        7.953         7.93         7.88        7.899
# 3  174.9309914  138.7068217  178.9540884  198.8711157  221.7636539
# 4      3089027      3060173      3051010      3039616      3026939
#
#           2005         2006        2007  ...         2015         2016  \
# 0     24404567     25424094    25909852  ...     33831764     34700612
# 1       22.703       22.907      23.113  ...       24.803        25.02
# 2        7.885        7.914       7.817  ...        9.052       10.133
# 3  254.1842491  274.2185536  376.223152  ...  565.5697304  522.0822156
# 4      3011487      2992547     2970017  ...      2880703      2876101
#
#           2017         2018         2019         2020         2021  \
# 0     35688935     36743039     37856121     39068979     40000412
# 1        25.25       25.495       25.754       26.026       26.314
# 2       11.184       11.196       11.185        11.71       11.994
# 3  525.4697709  491.3372214  496.6025043  510.7870634  356.4962141
# 4      2873457      2866376      2854191      2837849      2811666
#
#           2022         2023      2024
# 0     40578842     41454761  42647492
# 1       26.616       26.933    27.265
# 2         14.1       13.991    13.295
# 3  357.2611528  413.7578947        ..
# 4      2777689      2745972   2714617
#
# [5 rows x 27 columns]

# %% [markdown]
# #Take only years from 2000 to 2024 from the dataset and unpevot the dataset to make only column for the years and column for the indicators values

# %%
#Clean up column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head()

#fill non values with the mean
df = df.apply(lambda x: x.fillna(x.mean()) if x.dtype != 'object' else x)

# Identify year columns from 2000 to 2024
year_cols = [str(y) for y in range(2000, 2025) if str(y) in df.columns]

# Melt the dataset to convert years columns to one column
df_long = df.melt(
    id_vars=['country_name'],
    value_vars=year_cols,                       # columns to unpivot
    var_name='year',                            # new column name for years
    value_name='indicator_value'                # new column name for values
)
df_long.head()
# Out:
#   country_name  year indicator_value
# 0  Afghanistan  2000        20130327
# 1  Afghanistan  2000          22.078
# 2  Afghanistan  2000           7.935
# 3  Afghanistan  2000     174.9309914
# 4      Albania  2000         3089027

# %% [markdown]
# #Convert year to integer and drop missing values

# %%
df_long['year'] = df_long['year'].astype(int)
df_long.head()
# Out:
#   country_name  year indicator_value
# 0  Afghanistan  2000        20130327
# 1  Afghanistan  2000          22.078
# 2  Afghanistan  2000           7.935
# 3  Afghanistan  2000     174.9309914
# 4      Albania  2000         3089027

# %% [markdown]
# #Save the cleaned and reshaped data

# %%
df_long.to_csv("Clean_population.csv", index=False)
