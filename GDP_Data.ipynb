# %% [markdown]
# <a href="https://colab.research.google.com/github/Aminsfwt/Clean-Education-Indicators-using-pandas/blob/main/GDP_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tableau project on education story in this century using data from world bank**
#
# first download Education indecators from world bank in this link:
# https://data.worldbank.org/indicator

# %% [markdown]
# #Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #First load first dataset World_GDP

# %%
#load data
df = pd.read_csv("World_GDP.csv")

print(df.head())
# Out:
#            Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 0           Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1                Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2               Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...          2015          2016          2017          2018          2019  \
# 0  ...  1.913422e+10  1.811657e+10  1.875346e+10  1.805322e+10  1.879944e+10
# 1  ...  9.049642e+10  5.276162e+10  7.369015e+10  7.945069e+10  7.089796e+10
# 2  ...  1.147017e+10  1.198867e+10  1.325827e+10  1.537951e+10  1.558511e+10
# 3  ...  2.789881e+09  2.896610e+09  3.000162e+09  3.218420e+09  3.155149e+09
# 4  ...  3.702750e+11  3.692550e+11  3.905170e+11  4.270490e+11  4.179900e+11
#
#            2020          2021          2022          2023          2024
# 0  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN
# 1  4.850156e+10  6.650513e+10  1.044000e+11  8.487516e+10  8.039694e+10
# 2  1.524146e+10  1.803201e+10  1.901724e+10  2.354718e+10  2.717774e+10
# 3  2.891001e+09  3.324648e+09  3.380613e+09  3.785067e+09  4.039844e+09
# 4  3.494730e+11  4.151790e+11  5.027320e+11  5.141300e+11  5.370790e+11
#
# [5 rows x 67 columns]

# %% [markdown]
# #Take only years from 2000 to 2024 from the dataset and unpevot the dataset to make only column for the years and column for the indicators values

# %%
#Clean up column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head()

# Identify year columns from 2000 to 2024
year_cols = [str(y) for y in range(2000, 2025) if str(y) in df.columns]

# Melt the dataset to convert years columns to one column
df_long = df.melt(
    id_vars=['country_name'],
    value_vars=year_cols,                       # columns to unpivot
    var_name='year',                            # new column name for years
    value_name='indicator_value'                # new column name for values
)
df_long.head()
# Out:
#            country_name  year  indicator_value
# 0           Afghanistan  2000     3.521418e+09
# 1                Angola  2000     9.129595e+09
# 2               Albania  2000     3.584570e+09
# 3               Andorra  2000     1.432606e+09
# 4  United Arab Emirates  2000     1.043370e+11

# %% [markdown]
# #Convert year to integer and drop missing values

# %%
df_long['year'] = df_long['year'].astype(int)
df_long.dropna(subset=['indicator_value'], inplace=True)
df_long.head()
# Out:
#            country_name  year  indicator_value
# 0           Afghanistan  2000     3.521418e+09
# 1                Angola  2000     9.129595e+09
# 2               Albania  2000     3.584570e+09
# 3               Andorra  2000     1.432606e+09
# 4  United Arab Emirates  2000     1.043370e+11

# %% [markdown]
# #Save the cleaned and reshaped data

# %%
df_long.to_csv("Clean_World_GDP.csv", index=False)
